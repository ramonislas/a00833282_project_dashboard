# %%
import pandas as pd

# %%
df_full = pd.read_csv('final_database.csv')
df_full = df_full.drop(columns=['Unnamed: 0'])
df_full['date'] = pd.to_datetime(df_full['YEAR'].astype(str) + df_full['WEEK'].astype(str) + '1',format='%G%V%u')
df_full
# Out:
#              TP          SKU  WEEK  MONTH  YEAR Manuf_name         segment  \
# 0      CHEDRAUI  7MWET4027HW     1      1  2024  WHIRLPOOL  LAUNDRY CENTER
# 1      CHEDRAUI  7MWET4027HW     1     12  2024  WHIRLPOOL  LAUNDRY CENTER
# 2      CHEDRAUI  7MWET4027HW     2      1  2023  WHIRLPOOL  LAUNDRY CENTER
# 3      CHEDRAUI  7MWET4027HW     2      1  2025  WHIRLPOOL  LAUNDRY CENTER
# 4      CHEDRAUI  7MWET4027HW     3      1  2024  WHIRLPOOL  LAUNDRY CENTER
# ...         ...          ...   ...    ...   ...        ...             ...
# 30841   WALMART   WW21BTAHME    49     12  2024  WHIRLPOOL        TOP LOAD
# 30842   WALMART   WW21BTAHME    50     12  2023  WHIRLPOOL        TOP LOAD
# 30843   WALMART   WW21BTAHME    50     12  2024  WHIRLPOOL        TOP LOAD
# 30844   WALMART   WW21BTAHME    51     12  2023  WHIRLPOOL        TOP LOAD
# 30845   WALMART   WW21BTAHME    51     12  2024  WHIRLPOOL        TOP LOAD
#
#                       Segmento_Whp    fem    pol1  product_cost_mxn  \
# 0      145. STACKED LAUNDRY CENTER  0.125  0.1300      10044.575406
# 1      145. STACKED LAUNDRY CENTER  0.125  0.1300      10044.575406
# 2      145. STACKED LAUNDRY CENTER  0.125  0.1300      11101.899132
# 3      145. STACKED LAUNDRY CENTER  0.125  0.1300      10573.237269
# 4      145. STACKED LAUNDRY CENTER  0.125  0.1300      10044.575406
# ...                            ...    ...     ...               ...
# 30841    095. TL IMPELLER 20-24 KG  0.150  0.2079       4885.090000
# 30842    095. TL IMPELLER 20-24 KG  0.150  0.2079       5399.310000
# 30843    095. TL IMPELLER 20-24 KG  0.150  0.2079       4885.090000
# 30844    095. TL IMPELLER 20-24 KG  0.150  0.2079       5399.310000
# 30845    095. TL IMPELLER 20-24 KG  0.150  0.2079       4885.090000
#
#          unit_price    total_cost  quantity    gross_sales  avg_inventory_whp  \
# 0      11377.135000  14302.171081       2.0   22754.270000               0.50
# 1      14600.507292  15124.131015      12.0  145247.800000               2.25
# 2      21547.400000  18095.694093       1.0   21547.400000               1.00
# 3      15927.995000  16062.693099       0.0  -13652.650000               0.00
# 4      13273.270000  14785.685506       1.0   13273.270000               0.00
# ...             ...           ...       ...            ...                ...
# 30841   9705.992287   6131.870000      10.0  115277.769972               0.00
# 30842  10422.410000  10507.510539       1.0   10422.410000               0.00
# 30843   9705.992287   6131.870000       3.0   34366.288294               0.00
# 30844  12922.410000  11402.260539       1.0   12922.410000               0.00
# 30845   9705.992287   6131.870000       6.0   69676.121665               0.00
#
#        avg_inventory_sales          DCM  DCM_margin       date
# 0                      0.0 -2925.036081   -0.257098 2024-01-01
# 1                      0.0  -523.623723   -0.184944 2024-01-01
# 2                      0.0  3451.705907    0.160191 2023-01-09
# 3                      0.0  -134.698099   -0.177987 2025-01-06
# 4                      0.0 -1512.415506   -0.113944 2024-01-15
# ...                    ...          ...         ...        ...
# 30841                  0.0  3574.122287    0.368239 2024-12-02
# 30842                  0.0   -85.100539   -0.008165 2023-12-11
# 30843                  0.0  3574.122287    0.368239 2024-12-09
# 30844                  0.0  1520.149461    0.117637 2023-12-18
# 30845                  0.0  3574.122287    0.368239 2024-12-16
#
# [30846 rows x 20 columns]

# %%
df_full.dtypes
# Out:
# TP                             object
# SKU                            object
# WEEK                            int64
# MONTH                           int64
# YEAR                            int64
# Manuf_name                     object
# segment                        object
# Segmento_Whp                   object
# fem                           float64
# pol1                          float64
# product_cost_mxn              float64
# unit_price                    float64
# total_cost                    float64
# quantity                      float64
# gross_sales                   float64
# avg_inventory_whp             float64
# avg_inventory_sales           float64
# DCM                           float64
# DCM_margin                    float64
# date                   datetime64[ns]
# dtype: object
